# %% [markdown]
# * Named Entity Recognition (NER) is a key task in Natural Language Processing (NLP) that involves the identification and classification of named entities in unstructured text, such as people, organizations, locations, dates, and other relevant information.

# %%
sentence = "NER is used in various NLP applications such as information extraction, sentiment analysis, question-answering, and recommendation systems."

# %%
import nltk
nltk.download('punkt')
nltk.download('pos_tag')
nltk.download('averaged_perceptron_tagger')
words=nltk.word_tokenize(sentence)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Error loading pos_tag: Package 'pos_tag' not found in
# [nltk_data]     index
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# ## Use of Named Entity Recognition in NLP
# * **Information Exchange**
# * **Sentiment Analysis**
# * **Question-Answering**
# * **Recommendation Systems**

# %% [markdown]
# ## Advantages of Named Entity Recognition
# * **Improved Accuracy**
# * **Speed and Efficiency**
# * **Scalability**
# * **Personalization**

# %% [markdown]
# ## Disadvantages of Named Entity Recognition
# * **Ambiguity**
# * **Limited Scope**
# * **Data Requirements**
# * **Lannguage Dependency**
